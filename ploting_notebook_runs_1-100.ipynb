Y_django_ls_s=[0.06127031644185384, 0.6848633289337158, 1.3806780179341633, 2.0320626894632974, 2.685298442840576, 3.3051693439483643, 4.091670751571655, 4.844103574752808, 5.394703070322673, 6.156826734542847, 7.102831840515137]
Y_fastapi_ls_s=[0.015944401423136394, 0.11506978670756023, 0.1923069953918457, 0.30937902132670086, 0.450742244720459, 0.6798428694407145, 0.7967816193898519, 0.9846822420756022, 1.1275696754455566, 1.3684972127278645, 1.556621789932251]
Y_odmv1_ls_s=[0.03554844856262207, 0.42071859041849774, 1.046772877375285, 1.8797436555226643, 2.805002530415853, 5.008817672729492, 5.136614799499512, 7.026997884114583, 8.442356824874878, 10.449437379837036, 12.752883593241373]
Y_odmv2_ls_s=[0.024474700291951496, 0.20149604479471842, 0.4161062240600586, 0.702639102935791, 1.0615190664927165, 2.442871570587158, 1.9095778465270996, 2.255737622578939, 2.7423357168833413, 2.8506131172180176, 3.582406679789225]

# %%
import matplotlib.pyplot as plt

# %%
log=False
# fig, (ax1, ax2, ax3, ax4) = plt.subplots(2, 2)

fig=plt.figure(figsize=(12,8), dpi= 100, facecolor='w', edgecolor='k')
plt.subplots_adjust(hspace=0.4)

# - 1
plt.subplot(2, 2, 1)
plt.plot(X, Y_django_cr_p, color="blue", label="django")
plt.plot(X, Y_fastapi_cr_p, color="red", label="fastapi")
plt.plot(X, Y_odmv1_cr_p, color="green", label="odm")
plt.plot(X, Y_odmv2_cr_p, color="purple", label="biodm")

plt.legend()
plt.title('post parallel')
if log:
    plt.yscale('log')
plt.ylabel('seconds')
plt.xlabel('n requests')
plt.savefig('plot.png')

# - 2
plt.subplot(2, 2, 2)
plt.plot(X, Y_django_ls_p, color="lightblue", label="django")
plt.plot(X, Y_fastapi_ls_p, color="orange", label="fastapi")
plt.plot(X, Y_odmv1_ls_p, color="lightgreen", label="odm")
plt.plot(X, Y_odmv2_ls_p, color="violet", label="biodm")

plt.title('get parallel')
if log:
    plt.yscale('log')
plt.ylabel('seconds')
plt.xlabel('n requests')
plt.savefig('plot.png')

# - 3
plt.subplot(2, 2, 3)
plt.plot(X, Y_django_cr_s, color="blue", label="django")
plt.plot(X, Y_fastapi_cr_s, color="red", label="fastapi")
plt.plot(X, Y_odmv1_cr_s, color="green", label="odm")
plt.plot(X, Y_odmv2_cr_s, color="purple", label="biodm")

plt.legend()
plt.title('post sequencial')
if log:
    plt.yscale('log')
plt.ylabel('seconds')
plt.xlabel('n requests')
plt.savefig('plot.png')

# - 4
plt.subplot(2, 2, 4)
plt.plot(X, Y_django_ls_s, color="lightblue", label="django")
plt.plot(X, Y_fastapi_ls_s, color="orange", label="fastapi")
plt.plot(X, Y_odmv1_ls_s, color="lightgreen", label="odm")
plt.plot(X, Y_odmv2_ls_s, color="violet", label="biodm")

plt.title('get sequencial')
if log:
    plt.yscale('log')
plt.ylabel('seconds')
plt.xlabel('n requests')
plt.savefig('plot.png')
